# %% [markdown]
# <a href="https://colab.research.google.com/github/devashish10079/Data-Science/blob/main/OOPS(Lec_09).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class mirai_class:
  strength = 100
  teacher = ['A','B','C']
  div = ['alpha','beta']
  subjects = ['DSA','web-d','data science']

  # Constructor
  def __init__(self):

    print("Constructor called")

obj = mirai_class()
print(obj.strength)
print(obj.teacher)
print(obj.div)
print(obj.subjects)
# Out:
# Constructor called
# 100
# ['A', 'B', 'C']
# ['alpha', 'beta']
# ['DSA', 'web-d', 'data science']

# %%
class student:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def display(self):
    print('name:',self.name)
    print('age:',self.age)

a = student('Devashish',20)
# print(a.name)
# print(a.age)

a.display()
# Out:
# name: Devashish
# age: 20
